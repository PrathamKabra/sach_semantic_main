# %%
import pandas as pd
df = pd.read_csv('legal_transcriber/data/csv/ds.csv')
# Out:
# /var/folders/5_/7850fm454vb567dm0m8jx2d80000gn/T/ipykernel_94745/3920674012.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('legal_transcriber/data/csv/ds.csv')

# %%
df.head()
# Out:
#       id                   date_created                  date_modified source  \
# 0   9252  2014-11-18 22:47:38.243167+00  2018-08-27 23:21:21.794077+00      H
# 1  48623  2018-09-11 22:20:13.201834+00  2018-09-12 10:56:10.883635+00      C
# 2      2  2014-10-31 02:00:43.484241+00   2018-09-05 11:37:36.16048+00      C
# 3  32468  2017-10-18 20:37:57.964636+00  2018-08-29 01:29:54.022166+00      C
# 4  16109  2016-04-21 00:47:53.026143+00  2018-08-29 01:51:57.187461+00      C
#
#                         case_name_short                             case_name  \
# 0                                 Swift                     Swift v. Shinseki
# 1                                 Haque                       Haque v. Holder
# 2                         Figueroa-Lugo        United States v. Figueroa-Lugo
# 3                                   NaN        New Jersey Carpenters Health F
# 4  In Re Queen's University at Kingston  In Re Queen's University at Kingston
#
# ...
